# %%
import pandas as pd

# %%
df=pd.read_csv('services.csv')

# %%
df.describe()
# Out:
#              id  location_id  program_id
# count  23.00000    23.000000         0.0
# mean   12.00000    11.956522         NaN
# std     6.78233     6.711444         NaN
# min     1.00000     1.000000         NaN
# 25%     6.50000     6.500000         NaN
# 50%    12.00000    12.000000         NaN
# 75%    17.50000    17.500000         NaN
# max    23.00000    22.000000         NaN

# %% [markdown]
# # Using Matplot lib

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# doing the basic plot
x=np.linspace(0,10,50)
y=np.sin(x)
plt.plot(x,y)
plt.show()

# %%
# Customizing line style
plt.plot(x,y,color='red',marker='o',linestyle='--',linewidth=2)

# %%
plt.plot(x,y,color='red',marker='o',linestyle='-',linewidth=2)

# %%
plt.plot(x,y,label="sin(x)")

# %%
plt.plot(x,np.cos(x),label="cos(x)",linestyle=":")
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Subplots

# %%
# plt.subplot(nrows, ncols, index)

x=[1,2,3,4,5]
y=[10,20,30,40,50]

plt.subplot(2,2,1)

plt.plot(x,y)
plt.title("sub1")

plt.subplot(2,2,2)

plt.plot(x,y)
plt.title("sub2")
# Out:
# Text(0.5, 1.0, 'sub2')

# %%
# Histogram
data=np.random.randn(1000)
plt.hist(data,bins=10)
plt.grid(True)
plt.show()

# %%
datam=np.random.randn(100)
plt.hist(datam,bins=10)
plt.grid(True)
plt.show()

# %%
#using the random 
a=np.random.rand(30)
b=np.random.rand(30)
plt.hist([a,b],bins=15,stacked=True)
plt.show()

# %%
datam=np.random.rand(100)
dataz=np.random.rand(100)
plt.hist([datam,dataz],bins=30,stacked=True)
plt.grid(True)
plt.show()

# %%
x=np.random.rand(10)
y=np.random.rand(10)
plt.scatter(x,y)
plt.show()

# %%
# horizontal
categroy=['A','B','C']
values=[10,15,71]
plt.barh(categroy,values)
plt.show()

# %%
#pie chart
size=[10, 30, 50]
labels=['A','B','C']
plt.pie(size,labels=labels,shadow=True,startangle=90)
plt.axis('equal')
plt.show()

# %%
a=[10,20,30]
b=['swamy','Ammy','Zammy']
plt.pie(a,labels=b,shadow=True)
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Generate data
X = np.linspace(-5, 5, 50)
Y = np.linspace(-5, 5, 50)
X, Y = np.meshgrid(X, Y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Create figure and 3D axis
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Plot surface
ax.plot_surface(X, Y, Z, cmap='viridis')

# Labels
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_zlabel('Z Axis')
ax.set_title('3D Surface Plot')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')  # Corrected

x = np.random.rand(50)
y = np.random.rand(50)
z = np.random.rand(50)

ax.scatter(x, y, z)
plt.show()

# %%
# Used the area plot
Days = [1,2,3,4,5]
Sales = [100,200,300,400,500]
plt.fill_between(Days,Sales)
plt.show()

# %%
import seaborn as sns
import pandas as pd
data=pd.read_csv('services.csv')
sns.violinplot(x='accepted_payments',y='program_id')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       2 import pandas as pd
#       3 data=pd.read_csv('services.csv')
# ----> 4 sns.violinplot(x='accepted_payments',y='program_id')
#
# File c:\Users\swamy\AppData\Local\Programs\Python\Python313\Lib\site-packages\seaborn\categorical.py:1725, in violinplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, inner, split, width, dodge, gap, linewidth, linecolor, cut, gridsize, bw_method, bw_adjust, density_norm, common_norm, hue_norm, formatter, log_scale, native_scale, legend, scale, scale_hue, bw, inner_kws, ax, **kwargs)
#    1714 def violinplot(
#    1715     data=None, *, x=None, y=None, hue=None, order=None, hue_order=None,
#    1716     orient=None, color=None, palette=None, saturation=.75, fill=True,
#    (...)
#    1722     inner_kws=None, ax=None, **kwargs,
#    1723 ):
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
data = pd.read_csv("services.csv")  # Ensure the file path is correct

# Handle missing values
data.dropna(subset=['accepted_payments', 'program_id'], inplace=True)

# Create violin plot
plt.figure(figsize=(8, 6))
sns.violinplot(x='accepted_payments', y='program_id', data=data)

# Show plot
plt.show()
