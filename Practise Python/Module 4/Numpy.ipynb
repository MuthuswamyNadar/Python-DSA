# %%
import numpy as np

# %%
np.__version__
# Out:
# '2.2.1'

# %%
list=[1,2,3,4,5,6,7,7,8]
type(list)
# Out:
# list

# %%
ls=[1,2,3,4,5,6,7]
arrz=np.array(ls)
print(arrz)
# Out:
# [1 2 3 4 5 6 7]

# %%
type(arrz)
# Out:
# numpy.ndarray

# %%
# array can store homogenous data
ls=["swamy","money","bunny",1,2,3,4,5,6,7]
np.array(ls)
# Out:
# array(['swamy', 'money', 'bunny', '1', '2', '3', '4', '5', '6', '7'],
#       dtype='<U21')

# %%
# adding the 2 dimension array
arr12=np.array([[1,2,3,4],[4,5,6,7]])
arr12
# Out:
# array([[1, 2, 3, 4],
#        [4, 5, 6, 7]])

# %%
mns=np.array([[1,2,3,4,5],[21,22,23,24,25],[31,32,33,34,35],[41,42,43,44,45]])
mns
# Out:
# array([[ 1,  2,  3,  4,  5],
#        [21, 22, 23, 24, 25],
#        [31, 32, 33, 34, 35],
#        [41, 42, 43, 44, 45]])

# %%
mla=np.array([[1,2,3,4,5],[21,33,44,55,7],[1,2,3,4,5]])
type(mla)
# Out:
# numpy.ndarray

# %%
mtaz=np.array([[1,2,3,4,5],[22,33,44,55,66],[22,11,11,11,1]])
mtaz
# Out:
# array([[ 1,  2,  3,  4,  5],
#        [22, 33, 44, 55, 66],
#        [22, 11, 11, 11,  1]])

# %%
kyp=np.array([[1,2,3,4,5,6],[11,22,333,44,55,66],[11,22,11,11,1,1]])
kyp
# Out:
# array([[  1,   2,   3,   4,   5,   6],
#        [ 11,  22, 333,  44,  55,  66],
#        [ 11,  22,  11,  11,   1,   1]])

# %% [markdown]
# # creating the 3D array

# %%
ar3=np.array([
    [[1,2,3,4,5],[2,3,4,5,6],[11,22,33,44,55]],
    [[1,2,3,4,5],[22,11,22,44,55],[22,11,22,33,44]]
])
ar3
# Out:
# array([[[ 1,  2,  3,  4,  5],
#         [ 2,  3,  4,  5,  6],
#         [11, 22, 33, 44, 55]],
#
#        [[ 1,  2,  3,  4,  5],
#         [22, 11, 22, 44, 55],
#         [22, 11, 22, 33, 44]]])
