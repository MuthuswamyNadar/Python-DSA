# %% [markdown]
# # Basics of the lists

# %%
lists=["Hello","mine","love","working","peak"]
lists
# Out:
# ['Hello', 'mine', 'love', 'working', 'peak']

# %%
lists.append("swamy")

# %% [markdown]
# # Usecases

# %%
playlistz=[]
playlistz.append("swamyz")
playlistz.append("muthuz")
playlistz.append("moneyz")

# %%
playlistz
# Out:
# ['swamyz', 'muthuz', 'moneyz']

# %%
bodyshelf=[]
bodyshelf.append("GYM")
bodyshelf.append("swamy")
bodyshelf.append("money")

# %%
bodyshelf
# Out:
# ['GYM', 'swamy', 'money']

# %% [markdown]
# # Using the insert function()

# %%
list=["Manago","Apple","Organe","love"]
list.insert(1,"muthuswmayzzzz")

# %%
list
# Out:
# ['Manago', 'muthuswmayzzzz', 'Apple', 'Organe', 'love']

# %% [markdown]
# # Extend functions

# %%
mylist=["apple","banna","orange"]
brotherlist=["money","house","Success"]
brotherlist.extend(mylist)

# %%
brotherlist
# Out:
# ['money', 'house', 'Success', 'apple', 'banna', 'orange']

# %% [markdown]
# # Concatenate

# %%
myxlist=["Apple","b","trz"]
myzlisz=["m","n","L","k"]
myxlist+myzlisz
# Out:
# ['Apple', 'b', 'trz', 'm', 'n', 'L', 'k']

# %% [markdown]
# # Repeatation

# %%
"*" * 10
# Out:
# '**********'

# %%
"-" * 10
# Out:
# '----------'

# %%
"muthuswamy "* 99999
# Out:
# 'muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthuswamy muthusw
# ...

# %% [markdown]
# # Deep copy & Shallow copy

# %%
list1=123
list2= "ABC"
list1=list2

# %%
list1[0]
# Out:
# 'A'

# %%
list2[0]
# Out:
# 'A'

# %% [markdown]
# # Sorting the list

# %%
Booklist=["Datastr","Algorithmn","Beb"]
sorted(Booklist)
# Out:
# ['Algorithmn', 'Beb', 'Datastr']

# %%
Booklist.count("Beb")
# Out:
# 1

# %% [markdown]
# # Learning the list

# %%
mylix=["Swamy","nadar","love","mann"]

# %%
mylix[0]
# Out:
# 'Swamy'

# %%
print(mylix)
# Out:
# ['Swamy', 'nadar', 'love', 'mann']

# %%
mylix.append("Swamyz")

# %%
mylix
# Out:
# ['Swamy', 'nadar', 'love', 'mann', 'Swamyz']

# %%
mylix.extend("Hello swamy")

# %%
mylix
# Out:
# ['Swamy',
#  'nadar',
#  'love',
#  'mann',
#  'Swamyz',
#  'H',
#  'e',
#  'l',
#  'l',
#  'o',
#  ' ',
#  's',
#  'w',
#  'a',
#  'm',
#  'y']

# %%
print(mylix)
# Out:
# ['Swamy', 'nadar', 'love', 'mann', 'Swamyz', 'H', 'e', 'l', 'l', 'o', ' ', 's', 'w', 'a', 'm', 'y']

# %%
mylix.extend(["mello","challo"])
mylix
# Out:
# ['Swamy',
#  'nadar',
#  'love',
#  'mann',
#  'Swamyz',
#  'H',
#  'e',
#  'l',
#  'l',
#  'o',
#  ' ',
#  's',
#  'w',
#  'a',
#  'm',
#  'y',
#  'mello',
#  'challo']

# %%
mylix.insert(3,"Moneyz")

# %%
mylix
# Out:
# ['Swamy',
#  'nadar',
#  'love',
#  'Moneyz',
#  'mann',
#  'Swamyz',
#  'H',
#  'e',
#  'l',
#  'l',
#  'o',
#  ' ',
#  's',
#  'w',
#  'a',
#  'm',
#  'y',
#  'mello',
#  'challo']

# %%
mylix.remove("mello")

# %%
mylix
# Out:
# ['Swamy',
#  'nadar',
#  'love',
#  'Moneyz',
#  'mann',
#  'Swamyz',
#  'H',
#  'e',
#  'l',
#  'l',
#  'o',
#  ' ',
#  's',
#  'w',
#  'a',
#  'm',
#  'y',
#  'challo']

# %%
mylix.sort()

# %%
mylix
# Out:
# [' ',
#  'H',
#  'Moneyz',
#  'Swamy',
#  'Swamyz',
#  'a',
#  'challo',
#  'e',
#  'l',
#  'l',
#  'love',
#  'm',
#  'mann',
#  'nadar',
#  'o',
#  's',
#  'w',
#  'y']

# %%
print(mylix)
# Out:
# [' ', 'H', 'Moneyz', 'Swamy', 'Swamyz', 'a', 'challo', 'e', 'l', 'l', 'love', 'm', 'mann', 'nadar', 'o', 's', 'w', 'y']

# %%
mylix.reverse()

# %%
mylix
# Out:
# ['y',
#  'w',
#  's',
#  'o',
#  'nadar',
#  'mann',
#  'm',
#  'love',
#  'l',
#  'l',
#  'e',
#  'challo',
#  'a',
#  'Swamyz',
#  'Swamy',
#  'Moneyz',
#  'H',
#  ' ']
