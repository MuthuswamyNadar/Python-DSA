# %% [markdown]
# # Accessing / Changing the specififc elemetns rows & coloumns

# %%
import numpy as np

# %%
ab=np.array([[1,2,3,4,5,6,6,7],[10,22,33,44,66,77,88,99],
             [1,2,3,4,5,6,6,7],[10,22,33,44,66,77,88,99]])
print(ab)
# Out:
# [[ 1  2  3  4  5  6  6  7]
#  [10 22 33 44 66 77 88 99]
#  [ 1  2  3  4  5  6  6  7]
#  [10 22 33 44 66 77 88 99]]

# %%
ab.ndim
# Out:
# 2
