# %%
import pandas as pd

# Load CSVs using absolute paths
df1 = pd.read_csv(r"F:\Python\PW_Assignments\crypto_liquidity_project\data\coin_gecko_2022-03-16.csv")
df2 = pd.read_csv(r"F:\Python\PW_Assignments\crypto_liquidity_project\data\coin_gecko_2022-03-17.csv")

# Combine both datasets
df = pd.concat([df1, df2], ignore_index=True)

# Check the first few rows
print(df.head())
# Out:
#        coin symbol         price     1h    24h     7d    24h_volume  \
# 0   Bitcoin    BTC  40859.460000  0.022  0.030  0.055  3.539076e+10
# 1  Ethereum    ETH   2744.410000  0.024  0.034  0.065  1.974870e+10
# 2    Tether   USDT      1.000000 -0.001 -0.001  0.000  5.793497e+10
# 3       BNB    BNB    383.430000  0.018  0.028  0.004  1.395854e+09
# 4  USD Coin   USDC      0.999874 -0.001  0.000 -0.000  3.872274e+09
#
#         mkt_cap        date
# 0  7.709915e+11  2022-03-16
# 1  3.271044e+11  2022-03-16
# 2  7.996516e+10  2022-03-16
# 3  6.404382e+10  2022-03-16
# 4  5.222214e+10  2022-03-16

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# Assuming your DataFrame is named df

# Convert 'date' column to datetime if it exists
if 'date' in df.columns:
    df['date'] = pd.to_datetime(df['date'])

# Distribution of 'price'
plt.figure(figsize=(8, 6))
sns.histplot(df['price'], kde=True)
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# Correlation Heatmap for numerical columns only
numeric_cols = df.select_dtypes(include=[np.number]).columns

plt.figure(figsize=(10, 8))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# Time-series trend of 'price' over 'date' (if 'date' exists)
if 'date' in df.columns:
    plt.figure(figsize=(12, 6))
    sns.lineplot(data=df, x='date', y='price')
    plt.title("Price Over Time")
    plt.xlabel("Date")
    plt.ylabel("Price")
    plt.show()
